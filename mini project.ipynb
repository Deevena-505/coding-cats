# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd

# %%
a=pd.read_csv("C:/Users/91949/Desktop/OnlineFoodOrder.xls")

# %%
a
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
a.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
a.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
a.dropna()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
a.isnull()
# Out:
#        Age  Gender  Marital Status  Occupation  Monthly Income  \
# 0    False   False           False       False           False
# 1    False   False           False       False           False
# 2    False   False           False       False           False
# 3    False   False           False       False           False
# 4    False   False           False       False           False
# ..     ...     ...             ...         ...             ...
# 383  False   False           False       False           False
# 384  False   False           False       False           False
# 385  False   False           False       False           False
# 386  False   False           False       False           False
# 387  False   False           False       False           False
#
#      Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                         False        False     False      False     False
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(a["Gender"],bins=4,color="pink",edgecolor="black")
# Out:
# (array([166.,   0.,   0., 222.]),
#  array([0.  , 0.25, 0.5 , 0.75, 1.  ]),
#  <BarContainer object of 4 artists>)

# %%
plt.hist(a["Educational Qualifications"],bins=5,color="green",edgecolor="black")
# Out:
# (array([174., 177.,  23.,   2.,  12.]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. ]),
#  <BarContainer object of 5 artists>)

# %%
plt.bar(a['Gender'].value_counts().index,a['Feedback'].value_counts().values,color="orange",edgecolor="yellow")
plt.title("BG FOOD")
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
plt.bar(a['Gender'].value_counts().index,a['Output'].value_counts().values,color="blue",edgecolor="yellow")
plt.title("BG FOOD")
plt.xlabel('Gender')
# Out:
# Text(0.5, 0, 'Gender')

# %%
plt.bar(a['Feedback'].value_counts().index,a['Output'].value_counts().values,color="red",edgecolor="yellow")
plt.title("BG FOOD")
plt.xlabel('Feedback')
# Out:
# Text(0.5, 0, 'Feedback')

# %%
plt.boxplot(a['Age'])
plt.title('BP FOOD')
plt.xlabel('Age')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.boxplot(a['latitude'])
plt.title('BP FOOD')
plt.xlabel('Latitude')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.scatter(a['latitude'].value_counts().index,a['latitude'].value_counts().values,color="green",edgecolor="yellow")
plt.title("SP FOOD")
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %%
plt.scatter(a['longitude'].value_counts().index,a['longitude'].value_counts().values,color="blue",edgecolor="yellow")
plt.title("SP FOOD")
plt.xlabel('Latitude')
# Out:
# Text(0.5, 0, 'Latitude')

# %%
plt.hist(a["Marital Status"],bins=4,color="pink",edgecolor="black")
# Out:
# (array([268.,   0., 108.,  12.]),
#  array([0. , 0.5, 1. , 1.5, 2. ]),
#  <BarContainer object of 4 artists>)
